# %%
# not hardcoded version, but without plots

from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

import pandas as pd
import matplotlib.pyplot as plt

# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

# The ID and range of a sample spreadsheet.
# https://docs.google.com/spreadsheets/d/135mxNqqoqkki0uQjlez8V-4kxZCkor6qAW6voTX2xK0/edit?usp=sharing
SAMPLE_SPREADSHEET_ID = '135mxNqqoqkki0uQjlez8V-4kxZCkor6qAW6voTX2xK0'
SAMPLE_RANGE_NAME = 'A1:J30'

def main():
    """Shows basic usage of the Sheets API.
    Prints values from a sample spreadsheet.
    """
    creds = None
    # The file token.pickle stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)

    service = build('sheets', 'v4', credentials=creds)

    # Call the Sheets API
    sheet = service.spreadsheets()
    result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range=SAMPLE_RANGE_NAME).execute()
    values = result.get('values', [])
    
    if not values:
        print('No data found.')
    else:
        labels = ["Timestamp","Professor","Ease_ofA","Learning","Discussions","Easeof_Quiz","Deadlines","Consideration","Additional_comments"]
        df = pd.DataFrame.from_records(values,columns=labels)
        df.drop(df.index[0],inplace=True)
        df.reset_index(drop=True,inplace=True)
        df["Ease_ofA"] = pd.to_numeric(df["Ease_ofA"])
        df["Learning"] = pd.to_numeric(df["Learning"])
        df["Discussions"] = pd.to_numeric(df["Discussions"])
        df["Easeof_Quiz"] = pd.to_numeric(df["Easeof_Quiz"])
        df["Deadlines"] = pd.to_numeric(df["Deadlines"])
        df["Consideration"] = pd.to_numeric(df["Consideration"])
        
        FINALDICT = dict()
        
        
        NAMES = ["Ramil Battalier","Richard Eden","Clark Go","Lean Franzyl Yao"]
        DICT = dict()
        for NAME in NAMES:
            df_wa = sum(df[df["Professor"]==NAME].sum(axis=1))/len(df[df["Professor"]==NAME].sum(axis=1))
            df_wa = df_wa* 2
            individual_average = df[df["Professor"]==NAME][["Ease_ofA","Learning","Discussions","Easeof_Quiz","Deadlines","Consideration"]].sum()/len(df[df["Professor"]==NAME][["Professor"]])
            individual_average.sort_values(inplace=True,ascending=False)
            individual_average = individual_average*2
            
            DICT[NAME] = individual_average
            FINALDICT[NAME] = [individual_average,df_wa]

        key = list()
        value = list()
        CATEGORIES = ["Ease_ofA","Learning","Discussions","Easeof_Quiz","Deadlines","Consideration"]
        for category in CATEGORIES:
            STR = ""
            for k,v in DICT.items():
                key.append(k)
                value.append(v[category])
                STR = STR + str(k) + " : " + str(v[category]) + " "
                
            FINALDICT[category] = STR
        print(FINALDICT)
        
if __name__ == '__main__':
    main()

# %%
# THIS IS THE CORRECT ONE< WE SHOULD CHANGE DIFFCULTY OF QUIZ TO EASE OF QUIZ because higher scores means its easier which is good hence higher score

from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

import pandas as pd
import matplotlib.pyplot as plt

# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

# The ID and range of a sample spreadsheet.
# https://docs.google.com/spreadsheets/d/135mxNqqoqkki0uQjlez8V-4kxZCkor6qAW6voTX2xK0/edit?usp=sharing
SAMPLE_SPREADSHEET_ID = '135mxNqqoqkki0uQjlez8V-4kxZCkor6qAW6voTX2xK0'
SAMPLE_RANGE_NAME = 'A1:J30'

def main():
    """Shows basic usage of the Sheets API.
    Prints values from a sample spreadsheet.
    """
    creds = None
    # The file token.pickle stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)

    service = build('sheets', 'v4', credentials=creds)

    # Call the Sheets API
    sheet = service.spreadsheets()
    result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range=SAMPLE_RANGE_NAME).execute()
    values = result.get('values', [])
    
    if not values:
        print('No data found.')
    else:
        labels = ["Timestamp","Professor","Ease_ofA","Learning","Discussions","Easeof_Quiz","Deadlines","Consideration","Additional_comments"]
        df = pd.DataFrame.from_records(values,columns=labels)
        df.drop(df.index[0],inplace=True)
        df.reset_index(drop=True,inplace=True)
        df["Ease_ofA"] = pd.to_numeric(df["Ease_ofA"])
        df["Learning"] = pd.to_numeric(df["Learning"])
        df["Discussions"] = pd.to_numeric(df["Discussions"])
        df["Easeof_Quiz"] = pd.to_numeric(df["Easeof_Quiz"])
        df["Deadlines"] = pd.to_numeric(df["Deadlines"])
        df["Consideration"] = pd.to_numeric(df["Consideration"])
        
        while True:
            # for admu math professors
            Ramil_df_wa = sum(df[df["Professor"]=="Ramil Battalier"].sum(axis=1))/len(df[df["Professor"]=="Ramil Battalier"].sum(axis=1))
            Richard_df_wa = sum(df[df["Professor"]=="Richard Eden"].sum(axis=1))/len(df[df["Professor"]=="Richard Eden"].sum(axis=1))
            Clark_df_wa = sum(df[df["Professor"]=="Clark Go"].sum(axis=1))/len(df[df["Professor"]=="Clark Go"].sum(axis=1))
            Yao_df_wa = sum(df[df["Professor"]=="Lean Franzyl Yao"].sum(axis=1))/len(df[df["Professor"]=="Lean Franzyl Yao"].sum(axis=1))

            Ramil_individual_average = df[df["Professor"]=="Ramil Battalier"][["Ease_ofA","Learning","Discussions","Easeof_Quiz","Deadlines","Consideration"]].sum()/len(df[df["Professor"]=="Ramil Battalier"][["Professor"]])
            Ramil_individual_average.sort_values(inplace=True,ascending=False)
            Richard_individual_average = df[df["Professor"]=="Richard Eden"][["Ease_ofA","Learning","Discussions","Easeof_Quiz","Deadlines","Consideration"]].sum()/len(df[df["Professor"]=="Richard Eden"][["Professor"]])
            Richard_individual_average.sort_values(inplace=True,ascending=False)
            Clark_individual_average = df[df["Professor"]=="Clark Go"][["Ease_ofA","Learning","Discussions","Easeof_Quiz","Deadlines","Consideration"]].sum()/len(df[df["Professor"]=="Clark Go"][["Professor"]])
            Clark_individual_average.sort_values(inplace=True,ascending=False)
            Yao_individual_average = df[df["Professor"]=="Lean Franzyl Yao"][["Ease_ofA","Learning","Discussions","Easeof_Quiz","Deadlines","Consideration"]].sum()/len(df[df["Professor"]=="Lean Franzyl Yao"][["Professor"]])
            Yao_individual_average.sort_values(inplace=True,ascending=False)

            answer = input("Press 1 for information about Ramil Bataller\nPress 2 for information about Richard Eden\nPress 3 for information about Clark Go\nPress 4 for information about Lean Franzyl Yao\nPress 5 for comparison of ADMU Math Professors\nPress 6 for the different categories\nPress end to quit the program: ")
            if answer == "1":
                fig,ax = plt.subplots(1,1,figsize=(10,5))
                #Everything Ramil

                ax.bar(x=Ramil_individual_average.index,height=Ramil_individual_average)
                ax.set_xlabel("Different Criteria")
                ax.set_ylabel("Averages")
                ax.set_title("Ramil Bataller")
                print("The average weighted score is",Ramil_df_wa)
                
                plt.show()

            elif answer == "2":
                fig,ax = plt.subplots(1,1,figsize=(10,5))
                # Everything Richard

                ax.bar(x=Richard_individual_average.index,height=Richard_individual_average,color="Green")
                ax.set_xlabel("Different Criteria")
                ax.set_ylabel("Averages")
                ax.set_title("Richard Eden")
                print("The average weighted score is",Richard_df_wa)
                plt.show()

            elif answer == "3":
                fig,ax = plt.subplots(1,1,figsize=(10,5))
                # Everything Clark

                ax.bar(x=Clark_individual_average.index,height=Clark_individual_average,color="Orange")
                ax.set_xlabel("Different Criteria")
                ax.set_ylabel("Averages")
                ax.set_title("Clark Go")
                print("The average weighted score is",Clark_df_wa*2)
                plt.show()

            elif answer == "4":
                fig,ax = plt.subplots(1,1,figsize=(10,5))
                # Everything Yao


                ax.bar(x=Yao_individual_average.index,height=Yao_individual_average,color="Red")
                ax.set_xlabel("Different Criteria")
                ax.set_ylabel("Averages")
                ax.set_title("Lean Franzyl Yao")
                print("The average weighted score is",Yao_df_wa)
                plt.show()

            elif answer == "5":
                df_profs_wa = pd.DataFrame()
                df_profs_wa["Professors"] = df["Professor"].unique()
                df_profs_wa["Scores"] = [Ramil_df_wa,Richard_df_wa,Clark_df_wa,Yao_df_wa]
                df_profs_wa.sort_values(by="Scores",ascending=False,inplace=True)

                fig,ax = plt.subplots(1,1,figsize=(10,5))
                ax.bar(df_profs_wa["Professors"],df_profs_wa["Scores"])
                ax.set_xlabel("Professors")
                ax.set_ylabel("Average scores")
                ax.set_title("ADMU Math Professors")
                print("The average weighted of Ramil Bataller is",Ramil_df_wa)
                print("The average weighted of Richard Eden is",Richard_df_wa)
                print("The average weighted of Clark Go is",Clark_df_wa)
                print("The average weighted of Lean Franzyl Yao is",Yao_df_wa)
                plt.show()

            elif answer == "6":

                print()
                DICT = dict()
                DICT["Ramil Bataller"] = Ramil_individual_average
                DICT["Richard Eden"] = Richard_individual_average
                DICT["Clark Go"] = Clark_individual_average
                DICT["Lean Franzyl Yao"] = Yao_individual_average
                key = list()
                value = list()

                category = input("Enter A for Ease_of A\nEnter B for Learning\nEnter C for Dicussions\nEnter D for Easeof_Quiz\nEnter E for Deadlines\nEnter F for Consideration\nChoose category: ")
                print()
                if category == "A":
                    for k,v in DICT.items():
                        key.append(k)
                        value.append(v["Ease_ofA"])
                        print(k,":",v["Ease_ofA"]) 

                    PD = pd.Series(data=value,index=key)
                    PD.sort_values(inplace=True,ascending=False)

                    fig,ax = plt.subplots(1,1,figsize=(10,5))
                    ax.bar(PD.index,PD)
                    ax.set_xlabel("Professors")
                    ax.set_ylabel("Scores")
                    ax.set_title("Ease_ofA")
                    plt.show()

                elif category == "B":
                    for k,v in DICT.items():
                        key.append(k)
                        value.append(v["Learning"])
                        print(k,":",v["Learning"])

                    PD = pd.Series(data=value,index=key)
                    PD.sort_values(inplace=True,ascending=False)

                    fig,ax = plt.subplots(1,1,figsize=(10,5))
                    ax.bar(PD.index,PD)
                    ax.set_xlabel("Professors")
                    ax.set_ylabel("Scores")
                    ax.set_title("Learning")
                    plt.show()

                elif category == "C":
                    for k,v in DICT.items():
                        key.append(k)
                        value.append(v["Discussions"])
                        print(k,":",v["Discussions"])

                    PD = pd.Series(data=value,index=key)
                    PD.sort_values(inplace=True,ascending=False)

                    fig,ax = plt.subplots(1,1,figsize=(10,5))
                    ax.bar(PD.index,PD)
                    ax.set_xlabel("Professors")
                    ax.set_ylabel("Scores")
                    ax.set_title("Discussions")
                    plt.show()

                elif category == "D":
                    for k,v in DICT.items():
                        key.append(k)
                        value.append(v["Easeof_Quiz"])
                        print(k,":",v["Easeof_Quiz"]) 

                    PD = pd.Series(data=value,index=key)
                    PD.sort_values(inplace=True,ascending=False)

                    fig,ax = plt.subplots(1,1,figsize=(10,5))
                    ax.bar(PD.index,PD)
                    ax.set_xlabel("Professors")
                    ax.set_ylabel("Scores")
                    ax.set_title("Easeof_Quiz")
                    plt.show()

                elif category == "E":
                    for k,v in DICT.items():
                        key.append(k)
                        value.append(v["Deadlines"])
                        print(k,":",v["Deadlines"]) 

                    PD = pd.Series(data=value,index=key)
                    PD.sort_values(inplace=True,ascending=False)

                    fig,ax = plt.subplots(1,1,figsize=(10,5))
                    ax.bar(PD.index,PD)
                    ax.set_xlabel("Professors")
                    ax.set_ylabel("Scores")
                    ax.set_title("Deadlines")
                    plt.show()

                elif category == "F":
                    for k,v in DICT.items():
                        key.append(k)
                        value.append(v["Consideration"])
                        print(k,":",v["Consideration"]) 

                    PD = pd.Series(data=value,index=key)
                    PD.sort_values(inplace=True,ascending=False)

                    fig,ax = plt.subplots(1,1,figsize=(10,5))
                    ax.bar(PD.index,PD)
                    ax.set_xlabel("Professors")
                    ax.set_ylabel("Scores")
                    ax.set_title("Consideration")
                    plt.show()

                else:
                    print("wrong input")
                    pass

            elif answer == "end":
                break 
            else:
                print("wrong input")
                pass

        
if __name__ == '__main__':
    main()
